# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('accident data.csv')
data
# Out:
#                Index Accident_Severity Accident Date   Latitude  \
# 0      200701BS64157           Serious    05-06-2019  51.506187
# 1      200701BS65737           Serious    02-07-2019  51.495029
# 2      200701BS66127           Serious    26-08-2019  51.517715
# 3      200701BS66128           Serious    16-08-2019  51.495478
# 4      200701BS66837            Slight    03-09-2019  51.488576
# ...              ...               ...           ...        ...
# 67684  2007170L12557            Slight    07-11-2019  54.541730
# 67685  2007170L12627            Slight    31-12-2019  54.534521
# 67686  2007170L12647            Slight    23-08-2019  54.535740
# 67687  2007170L20087            Slight    23-01-2019  54.554111
# 67688  2007170L20137            Slight    29-01-2019  54.578922
#
#                   Light_Conditions           District Area  Longitude  \
# 0            Darkness - lights lit  Kensington and Chelsea  -0.209082
# 1                         Daylight  Kensington and Chelsea  -0.173647
# 2      Darkness - lighting unknown  Kensington and Chelsea  -0.210215
# 3                         Daylight  Kensington and Chelsea  -0.202731
# 4            Darkness - lights lit  Kensington and Chelsea  -0.192487
# ...                            ...                     ...        ...
# 67684                     Daylight    Redcar and Cleveland  -1.036060
# 67685                     Daylight    Redcar and Cleveland  -1.056476
# 67686                     Daylight    Redcar and Cleveland  -1.051502
# 67687        Darkness - lights lit    Redcar and Cleveland  -1.166269
# 67688                     Daylight    Redcar and Cleveland  -1.141470
#
#        Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 0                       1.0                 2.0                     Dry
# 1                       1.0                 2.0             Wet or damp
# 2                       1.0                 3.0                     Dry
# 3                       1.0                 4.0                     Dry
# 4                       1.0                 2.0                     Dry
# ...                     ...                 ...                     ...
# 67684                   1.0                 1.0                     Dry
# 67685                   1.0                 1.0             Wet or damp
# 67686                   2.0                 2.0                     Dry
# 67687                   1.0                 2.0             Wet or damp
# 67688                   NaN                 NaN                     NaN
#
#                 Road_Type Urban_or_Rural_Area     Weather_Conditions  \
# 0      Single carriageway               Urban     Fine no high winds
# 1      Single carriageway               Urban  Raining no high winds
# 2                     NaN               Urban                    NaN
# 3      Single carriageway               Urban     Fine no high winds
# 4                     NaN               Urban                    NaN
# ...                   ...                 ...                    ...
# 67684  Single carriageway               Rural     Fine no high winds
# 67685  Single carriageway               Urban     Fine no high winds
# 67686  Single carriageway               Urban     Fine no high winds
# 67687  Single carriageway               Urban     Fine no high winds
# 67688                 NaN                 NaN                    NaN
#
#                                Vehicle_Type
# 0                                       Car
# 1                                       Car
# 2                     Taxi/Private hire car
# 3      Bus or coach (17 or more pass seats)
# 4                             Other vehicle
# ...                                     ...
# 67684                                   Car
# 67685                                   Car
# 67686                                   Car
# 67687                                   Car
# 67688                                   NaN
#
# [67689 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67689 entries, 0 to 67688
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Index                    67689 non-null  object
#  1   Accident_Severity        67689 non-null  object
#  2   Accident Date            67689 non-null  object
#  3   Latitude                 67689 non-null  float64
#  4   Light_Conditions         67689 non-null  object
#  5   District Area            67689 non-null  object
#  6   Longitude                67689 non-null  float64
#  7   Number_of_Casualties     67688 non-null  float64
#  8   Number_of_Vehicles       67688 non-null  float64
#  9   Road_Surface_Conditions  67666 non-null  object
#  10  Road_Type                66876 non-null  object
#  11  Urban_or_Rural_Area      67688 non-null  object
#  12  Weather_Conditions       66452 non-null  object
#  13  Vehicle_Type             67688 non-null  object
# dtypes: float64(4), object(10)
# memory usage: 7.2+ MB

# %%
# Handle missing values and clean the data
data.dropna(inplace=True)


data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65900 entries, 0 to 67687
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Index                    65900 non-null  object
#  1   Accident_Severity        65900 non-null  object
#  2   Accident Date            65900 non-null  object
#  3   Latitude                 65900 non-null  float64
#  4   Light_Conditions         65900 non-null  object
#  5   District Area            65900 non-null  object
#  6   Longitude                65900 non-null  float64
#  7   Number_of_Casualties     65900 non-null  float64
#  8   Number_of_Vehicles       65900 non-null  float64
#  9   Road_Surface_Conditions  65900 non-null  object
#  10  Road_Type                65900 non-null  object
#  11  Urban_or_Rural_Area      65900 non-null  object
#  12  Weather_Conditions       65900 non-null  object
#  13  Vehicle_Type             65900 non-null  object
# dtypes: float64(4), object(10)
# memory usage: 7.5+ MB

# %%
data.describe(include = 'all')
# Out:
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#            Index Accident_Severity Accident Date      Latitude  \
# count      65900             65900         65900  65900.000000
# unique     47272                 3           365           NaN
# top     2.01E+12            Slight    20-11-2019           NaN
# freq       18629             55948           261           NaN
# mean         NaN               NaN           NaN     53.032677
# std          NaN               NaN           NaN      1.180709
# min          NaN               NaN           NaN     51.292694
# 25%          NaN               NaN           NaN     51.549322
# 50%          NaN               NaN           NaN     53.457307
# 75%          NaN               NaN           NaN     53.774698
# max          NaN               NaN           NaN     55.785544
#
#        Light_Conditions District Area     Longitude  Number_of_Casualties  \
# count             65900         65900  65900.000000          65900.000000
# unique                5           120           NaN                   NaN
# top            Daylight         Leeds           NaN                   NaN
# freq              48047          2397           NaN                   NaN
# mean                NaN           NaN     -1.337871              1.364340
# std                 NaN           NaN      1.060510              0.842902
# min                 NaN           NaN     -3.599412              1.000000
# 25%                 NaN           NaN     -2.258552              1.000000
# 50%                 NaN           NaN     -1.479972              1.000000
# 75%                 NaN           NaN     -0.191538              1.000000
# max                 NaN           NaN      0.313329             40.000000
#
#         Number_of_Vehicles Road_Surface_Conditions           Road_Type  \
# count         65900.000000                   65900               65900
# unique                 NaN                       5                   5
# top                    NaN                     Dry  Single carriageway
# freq                   NaN                   47266               50126
# mean              1.828225                     NaN                 NaN
# std               0.691395                     NaN                 NaN
# min               1.000000                     NaN                 NaN
# 25%               1.000000                     NaN                 NaN
# 50%               2.000000                     NaN                 NaN
# 75%               2.000000                     NaN                 NaN
# max              14.000000                     NaN                 NaN
#
#        Urban_or_Rural_Area  Weather_Conditions Vehicle_Type
# count                65900               65900        65900
# unique                   2                   8           14
# top                  Urban  Fine no high winds          Car
# freq                 51240               54376        46659
# mean                   NaN                 NaN          NaN
# std                    NaN                 NaN          NaN
# min                    NaN                 NaN          NaN
# 25%                    NaN                 NaN          NaN
# 50%                    NaN                 NaN          NaN
# 75%                    NaN                 NaN          NaN
# max                    NaN                 NaN          NaN

# %%
data.head(10)
# Out:
#             Index Accident_Severity Accident Date   Latitude  \
# 0   200701BS64157           Serious    05-06-2019  51.506187
# 1   200701BS65737           Serious    02-07-2019  51.495029
# 3   200701BS66128           Serious    16-08-2019  51.495478
# 5   200701BS67159           Serious    18-09-2019  51.497750
# 6   200701BS67207           Serious    05-09-2019  51.501405
# 7   200701BS67370             Fatal    03-10-2019  51.482260
# 8   200701BS67515            Slight    31-10-2019  51.493319
# 9   200701BS67543            Slight    18-10-2019  51.484539
# 10  200701BS67644           Serious    09-10-2019  51.491944
# 11  200701BS67747             Fatal    02-11-2019  51.499127
#
#          Light_Conditions           District Area  Longitude  \
# 0   Darkness - lights lit  Kensington and Chelsea  -0.209082
# 1                Daylight  Kensington and Chelsea  -0.173647
# 3                Daylight  Kensington and Chelsea  -0.202731
# 5                Daylight  Kensington and Chelsea  -0.192556
# 6                Daylight  Kensington and Chelsea  -0.161577
# 7   Darkness - lights lit  Kensington and Chelsea  -0.179486
# 8   Darkness - lights lit  Kensington and Chelsea  -0.173572
# 9                Daylight  Kensington and Chelsea  -0.175651
# 10  Darkness - lights lit  Kensington and Chelsea  -0.171898
# 11               Daylight  Kensington and Chelsea  -0.159652
#
#     Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 0                    1.0                 2.0                     Dry
# 1                    1.0                 2.0             Wet or damp
# 3                    1.0                 4.0                     Dry
# 5                    2.0                 3.0                     Dry
# 6                    1.0                 2.0                     Dry
# 7                    3.0                 2.0                     Dry
# 8                    1.0                 2.0                     Dry
# 9                    1.0                 2.0                     Dry
# 10                   1.0                 2.0                     Dry
# 11                   1.0                 2.0                     Dry
#
#              Road_Type Urban_or_Rural_Area     Weather_Conditions  \
# 0   Single carriageway               Urban     Fine no high winds
# 1   Single carriageway               Urban  Raining no high winds
# 3   Single carriageway               Urban     Fine no high winds
# 5   Single carriageway               Urban     Fine no high winds
# 6     Dual carriageway               Urban     Fine no high winds
# 7   Single carriageway               Urban     Fine no high winds
# 8   Single carriageway               Urban     Fine no high winds
# 9   Single carriageway               Urban     Fine no high winds
# 10  Single carriageway               Urban     Fine no high winds
# 11  Single carriageway               Urban     Fine no high winds
#
#                              Vehicle_Type
# 0                                     Car
# 1                                     Car
# 3    Bus or coach (17 or more pass seats)
# 5                                     Car
# 6     Van / Goods 3.5 tonnes mgw or under
# 7                                     Car
# 8                                     Car
# 9   Motorcycle over 125cc and up to 500cc
# 10          Goods 7.5 tonnes mgw and over
# 11   Bus or coach (17 or more pass seats)

# %%
plt.figure(figsize=(8, 8))
sns.countplot(x='Accident_Severity', data=data, hue='Urban_or_Rural_Area')
plt.title('Accident Severity by Area of Accident')
plt.xlabel('Accident Severity')
plt.ylabel('Number of Accidents')
plt.show()

# %%
light_conditions_counts = data['Light_Conditions'].value_counts()
print(light_conditions_counts)

plt.figure(figsize=(10, 8))
sns.barplot(x=light_conditions_counts.index, y=light_conditions_counts.values)
plt.title('Distribution of Accidents by Light Conditions')
plt.xlabel('Light Conditions')
plt.ylabel('Number of Accidents')
plt.show()
# Out:
# Daylight                       48047
# Darkness - lights lit          15283
# Darkness - no lighting          1903
# Darkness - lighting unknown      472
# Darkness - lights unlit          195
# Name: Light_Conditions, dtype: int64

# %%
plt.figure(figsize=(10, 8))
sns.countplot(x='Accident_Severity', data=data, hue='Light_Conditions')
plt.title('Accident Severity by Light Conditions')
plt.xlabel('Accident Severity')
plt.ylabel('Number of Accidents')
plt.show()

# %%
# Time analysis
data['Accident Date'] = pd.to_datetime(data['Accident Date'])
data['Month'] = data['Accident Date'].dt.month
plt.figure(figsize=(12, 6))
sns.countplot(x='Month', data=data, hue='Accident_Severity')
plt.title('Accidents by Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-30-9fd753c09edb>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['Accident Date'] = pd.to_datetime(data['Accident Date'])

# %%
plt.figure(figsize=(10, 8))
sns.countplot(x='Accident_Severity', data=data, hue='Road_Surface_Conditions')
plt.title('Accident Severity by Road Surface Condition')
plt.xlabel('Accident Severity')
plt.ylabel('Number of Accidents')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Weather_Conditions', data=data, palette='viridis')
plt.title('Distribution of Weather Conditions')
plt.xlabel('Weather Conditions')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-32-ae8ce962fd9b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Weather_Conditions', data=data, palette='viridis')

# %%
plt.figure(figsize=(10, 8))
columns = ['Latitude', 'Longitude', 'Number_of_Casualties', 'Number_of_Vehicles', 'Month']
correlation_matrix = data[columns].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix')
plt.show()
